# %%
import numpy as np

# %%
import subprocess
from pathlib import Path
project_root = Path(subprocess.check_output(["git", "rev-parse", "--show-toplevel"], text=True).strip())

# %%
project_root
# Out:
# PosixPath('/home/rahul/Documents/codes/DeepUnderstandingOfDeepLearning')

# %%
data = np.loadtxt(open(project_root / 'sample_data/mnist_train_small.csv','rb'),delimiter=',')
data.shape
# Out:
# (20000, 785)
